# %% [markdown]
# # Volatility 3 Memory Forensics
#
# This notebook provides access to Volatility 3 for memory analysis.
#
# ## Quick Start
#
# 1. Your evidence files are mounted in `/evidence`
# 2. Output files will be saved to `/output`
# 3. Use the commands below to analyze memory dumps

# %%
# List available plugins
# !vol -h

# %%
# Example: List processes from a memory dump
# Replace memory.raw with your evidence file
# !vol -f /evidence/memory.raw windows.pslist

# %%
# Example: List network connections
# !vol -f /evidence/memory.raw windows.netscan

# %% [markdown]
# ## Common Volatility Commands
#
# - `windows.pslist` - List processes
# - `windows.pstree` - Process tree
# - `windows.netscan` - Network connections
# - `windows.filescan` - File scan
# - `windows.cmdline` - Command line arguments
# - `windows.dlllist` - DLL list for processes
# - `windows.handles` - Open handles
# - `windows.registry.hivelist` - Registry hives
